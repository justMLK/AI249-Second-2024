# %%
import pandas as pd  
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler  
from sklearn.ensemble import RandomForestClassifier 
from sklearn.metrics import f1_score  
# قراءة ملفات البيانات
train_data = pd.read_csv('/kaggle/input/just-ai-249-machine-learning-lab-competition/spambase_train.csv')
test_data = pd.read_csv('/kaggle/input/just-ai-249-machine-learning-lab-competition/spambase_test.csv')

# تقسيم بيانات التدريب إلى متغيرات التحرير والاختبار
train_xxx = train_data.drop('spam', axis=1)
train_yyy = train_data['spam']

# تطبيق تقنية Standard Scaling لمعالجة بيانات التدريب
scal = StandardScaler() 
train_xxx_scal = scal.fit_transform(train_xxx)  # تطبيق تقنية Standard Scaling وتخزين النتائج في train_xxx_scal

# تدريب نموذج RandomForestClassifier على بيانات التدريب المعالجة
rf = RandomForestClassifier(random_state=40) #   اكثر من مره للوصول الى افضل مستوىrandom_stateلقد قمت بتغيير  
rf.fit(train_xxx_scal, train_yyy)  

# تطبيق تقنية Standard Scaling على بيانات الاختبار
test_xxx_scal = scal.transform(test_data)  

# توقع فئة 'spam' باستخدام النموذج RandomForestClassifier
y_pred_rf = random_forest.predict(test_xxx_scal)  

# إنشاء DataFrame يحتوي على معلومات الـ ID والتصنيفات المتوقعة للرسائل (spam أو non-spam)
submission_rf = pd.DataFrame({'ID': test_data['ID'], 'spam': y_pred_rf})

# حفظ DataFrame كملف CSV باسم 'ammoo.csv' دون إضافة مؤشرات الصفوف
submission_rf.to_csv('ammoou.csv', index=False)

# %%
import matplotlib.pyplot as plt

# Plotting the data
plt.figure(figsize=(10, 6))
plt.scatter(train_xxx_scal[:, 0], train_xxx_scal[:, 1], c=train_yyy, cmap='viridis')
plt.title('Scatter Plot of Scaled Training Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.colorbar(label='Spam')
plt.grid(True)
plt.show()

# %%
# Plotting the features
plt.figure(figsize=(10, 6))
plt.bar(range(len(random_forest.feature_importances_)), random_forest.feature_importances_)
plt.title('Feature Importances')
plt.xlabel('Feature Index')
plt.ylabel('Importance')
plt.grid(True)
plt.show()
