# %% [markdown]
# # # AbdelRhman Emad Alsheyab 16437

# %% [markdown]
# # importing the important functions and libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split # This function is used to split datasets into random train and test subsets
from sklearn.preprocessing import StandardScaler # used to standardize features by removing the mean and scaling to unit variance
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score

# %% [markdown]
# # reading data from CSV files using Pandas

# %%
training_df = pd.read_csv('/kaggle/input/just-ai-249-machine-learning-lab-competition/spambase_train.csv')
testing_df = pd.read_csv('/kaggle/input/just-ai-249-machine-learning-lab-competition/spambase_test.csv')

# %% [markdown]
# # Accessing the data

# %%
x_train = training_df.drop(columns=['spam', 'ID'])  # Features
y_train = training_df['spam']  # Labels
x_test = testing_df.drop(columns=['ID'])

# %% [markdown]
# # Train validation split

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=42)

# %% [markdown]
# # Handling missing values

# %%
x_train = x_train.dropna() # This method is used to remove any rows with missing values from both the training and validation sets
x_val = x_val.dropna()

# %% [markdown]
# # Standardizing Features

# %%
# Standardize the features
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_val_scaled = scaler.transform(x_val)
x_test_scaled = scaler.transform(x_test)  # Apply the same transformation to the test set

# %% [markdown]
# # Make predictoins on the validation set

# %%
y_val_pred = svm_model.predict(x_val_scaled)

# %% [markdown]
# # Train the SVM model

# %%
# Train the SVM model
svm_model = SVC(kernel='linear')
svm_model.fit(x_train_scaled, y_train)

# Evaluate the model on the testing set
val_accuracy = accuracy_score(y_val, y_val_pred)
val_f1_score = f1_score(y_val, y_val_pred)
print(f'Accuracy: {val_accuracy * 100:.4f}%')
print(f'F1-Score: {val_f1_score:.4f}')
# Out:
# Accuracy: 93.4161%
# F1-Score: 0.9121

# %% [markdown]
# # Evaluate the model on the testing set

# %%
val_accuracy = accuracy_score(y_val, y_val_pred)
val_f1_score = f1_score(y_val, y_val_pred)
print(f'Accuracy: {val_accuracy * 100:.4f}%')
print(f'F1-Score: {val_f1_score:.4f}')
# Out:
# Accuracy: 93.4161%
# F1-Score: 0.9121

# %% [markdown]
# # Make predictions on the test set and Submission the file

# %%
y_test_pred = svm_model.predict(x_test_scaled)
file_submission = pd.DataFrame({'ID': testing_df['ID'], 'spam':y_test_pred})
file_submission.to_csv("omdehhhh.csv", index = False)
